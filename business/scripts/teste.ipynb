# %%
import pandas as pd

# %%
df = pd.read_excel('acrux_emissao geru 7_20250411.xlsx', sheet_name='01_Cadastro', engine='openpyxl')

# %%
df
# Out:
#                            contract_id  borrower_document  \
# 0     00055efb4d504248a9b4b83667d42cbe        39592601801
# 1     001e919215664f30af8b3470e74bffbc        13503343750
# 2     002856690ee848b0ac3b39ea29a73389        57682879572
# 3     003be6dd7f324c5695de37883687ae1a         6192429901
# 4     004359b6339f4421bdb58cd8da65ac55         9898879793
# ...                                ...                ...
# 3760  ff812d46b8a84723b098e9e2ebb5c454        36941546808
# 3761  ff8a4562c01046d4814a23ba2bd897ad        31623118883
# 3762  ff9072bfcd0b406d98ca27b21097ed3a        14295121568
# 3763  ffd660b5ac384624ac716d4186935e6c         1782812121
# 3764  ffee3e08801f403286195bb4a791ce4b         7426010805
#
#                            borrower_name  client_id      current_fund  \
# 0                 MARINA DE ARAUJO COSTA    2266730  DEBENTURE GERU 7
# 1              Poliana Lagreca da  Silva    1332744  DEBENTURE GERU 7
# ...

# %%
df.to_excel("PESSOAS_GERU.xlsx")

# %%
df['borrower_name'] = df['borrower_name'].str.encode('utf-8').str.decode('latin1')

# %%
df.drop_duplicates(subset='borrower_document')
# Out:
#       contract_id  borrower_document                       borrower_name  \
# 0        10000503        96174579204     JosÃ© Orlando Nunes de Oliveira
# 1        10001143         3634139870            marco antonio de gouveia
# 2        10002934        72912596904            Cesar Augusto Teodoroves
# 3        10003141         9738904790             Felipe Lyra de Oliveira
# 4        10003478        44682676822                 alice braga moreira
# ...           ...                ...                                 ...
# 6262      9967647         2053921307           JoÃ£o Kenes Tavares Silva
# 6263      9982071          237439131                Bruno Silva de Paiva
# 6264      9996092        42713631890                Caio Bezerra Botelho
# 6265      9996676        12632668867  CÃ­cero Rodrigues da Silva JÃºnior
# 6266     12063993         1699191107                  Alexandre canteiro
#
#         client_id       current_fund borrower_state   borrower_city  \
# ...

# %%
df['borrower_name']
# Out:
# 0        Jos Orlando Nunes de Oliveira
# 1             marco antonio de gouveia
# 2             Cesar Augusto Teodoroves
# 3              Felipe Lyra de Oliveira
# 4                  alice braga moreira
#                      ...
# 6262           Joo Kenes Tavares Silva
# 6263              Bruno Silva de Paiva
# 6264              Caio Bezerra Botelho
# 6265    Ccero Rodrigues da Silva Jnior
# 6266                Alexandre canteiro
# Name: borrower_name, Length: 6267, dtype: object

# %%
df['borrower_name'].str.encode('utf-8')
# Out:
# 0        b'Jos\xc3\x83\xc2\xa9 Orlando Nunes de Oliveira'
# 1                             b'marco antonio de gouveia'
# 2                             b'Cesar Augusto Teodoroves'
# 3                              b'Felipe Lyra de Oliveira'
# 4                                  b'alice braga moreira'
#                               ...
# 6262           b'Jo\xc3\x83\xc2\xa3o Kenes Tavares Silva'
# 6263                              b'Bruno Silva de Paiva'
# 6264                              b'Caio Bezerra Botelho'
# 6265    b'C\xc3\x83\xc2\xadcero Rodrigues da Silva J\x...
# 6266                                b'Alexandre canteiro'
# Name: borrower_name, Length: 6267, dtype: object

# %%
df
# Out:
#       contract_id  borrower_document                       borrower_name  \
# 0        10000503        96174579204     JosÃ© Orlando Nunes de Oliveira
# 1        10001143         3634139870            marco antonio de gouveia
# 2        10002934        72912596904            Cesar Augusto Teodoroves
# 3        10003141         9738904790             Felipe Lyra de Oliveira
# 4        10003478        44682676822                 alice braga moreira
# ...           ...                ...                                 ...
# 6262      9967647         2053921307           JoÃ£o Kenes Tavares Silva
# 6263      9982071          237439131                Bruno Silva de Paiva
# 6264      9996092        42713631890                Caio Bezerra Botelho
# 6265      9996676        12632668867  CÃ­cero Rodrigues da Silva JÃºnior
# 6266     12063993         1699191107                  Alexandre canteiro
#
#         client_id       current_fund borrower_state   borrower_city  \
# ...
